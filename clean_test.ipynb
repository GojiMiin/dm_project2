# %%
import pandas as pd
import numpy as np

# %%
readIn = pd.read_csv('./bank/bank.csv')

# %%
raw = readIn.iloc[:,0]

# %%
age = []
job = []
marital = []
edu = []
default = []
balance = []
housing = []
loan = []
contact = []
day = []
month = []
duration = []
campaign = []
pdays = []
previous = []
poutcome = []
y = []

# %%
for i in raw:
    lineArr = i.split(";")
    
    age.append(int(lineArr[0]))
    job.append(lineArr[1].replace('"', ''))
    marital.append(lineArr[2].replace('"', ''))
    edu.append(lineArr[3].replace('"', ''))
    default.append(lineArr[4].replace('"', ''))
    balance.append(int(lineArr[5]))
    housing.append(lineArr[6].replace('"', ''))
    loan.append(lineArr[7].replace('"', ''))
    contact.append(lineArr[8].replace('"', ''))
    day.append(int(lineArr[9]))
    month.append(lineArr[10].replace('"', ''))
    duration.append(int(lineArr[11]))
    campaign.append(int(lineArr[12]))
    pdays.append(int(lineArr[13]))
    previous.append(int(lineArr[14]))
    poutcome.append(lineArr[15].replace('"', ''))
    y.append(lineArr[16].replace('"', ''))

# %%
zippedList =  list(zip(age, job, marital, edu, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, y))

# %%
new_pd = pd.DataFrame(zippedList, columns = ['age' , 'job', 'marital', 'edu', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y'])

# %%
new_pd
# Out:
#       age            job  marital        edu default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
new_pd.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
balance_row = new_pd.iloc[:,5]
type(balance_row)
# Out:
# pandas.core.series.Series

# %%
quantile1, quantile3 = np.percentile(balance_row,[25,75]) #25,75 percentile
print(quantile1, quantile3)
# Out:
# 69.0 1480.0

# %%
## Find the IQR

iqr_value = quantile3 - quantile1
print(iqr_value)
# Out:
# 1411.0

# %%
## Find the lower bound value and the higher bound value

lower_bound_val = quantile1 - (1.5 * iqr_value) 
upper_bound_val = quantile3 + (1.5 * iqr_value)
print(lower_bound_val,upper_bound_val)
# Out:
# -2047.5 3596.5

# %%
count = 0
for each_balance_row in balance_row:
    if(each_balance_row > upper_bound_val or each_balance_row < lower_bound_val):
        count = count + 1
print(count)
# Out:
# 506

# %%
for index,row in new_pd.iterrows():
    print(row['balance'], row['duration'])
# Out:
# 1787 79
# 4789 220
# 1350 185
# 1476 199
# 0 226
# 747 141
# 307 341
# 147 151
# 221 57
# -88 313
# 9374 273
# 264 113
# 1109 328
# 502 261
# 360 89
# 194 189
# 4073 239
# 2317 114
# -221 250
# 132 148
# 0 96
# 16 140
# 106 109
# 93 125
# 543 169
# 5883 182
# 627 247
# 696 119
# 784 149
# 105 74
# 4189 897
# 171 81
# 42 40
# 2536 958
# 1235 354
# 1811 150
# 229 97
# 2089 132
# 3935 765
# 363 16
# 11971 609
# 553 106
# 1117 365
# 396 205
# 2204 11
# 872 105
# 145 59
# 0 425
# -849 204
# 4629 181
# 844 1018
# 228 1740
# 50 98
# 1539 441
# 2231 272
# 3064 159
# 82 140
# 2155 295
# 101 314
# 784 579
# -516 554
# 415 323
# 5887 227
# 1355 134
# 16873 223
# 203 134
# 338 155
# 444 130
# 0 630
# 360 164
# 0 268
# 2 380
# 6248 154
# 412 154
# 344 221
# 3222 67
# 174 367
# 591 87
# 388 701
# 219 204
# 451 652
# 5 63
# 177 150
# 657 398
# 1315 224
# 1466 406
# 879 60
# 293 521
# 424 279
# 1831 203
# 111 201
# 455 372
# -195 391
# 3616 165
# 14093 231
# 1567 291
# 5426 149
# 261 233
# 2843 473
# ...

# %%
# new_pd.to_csv("./clean.csv", index=False)
